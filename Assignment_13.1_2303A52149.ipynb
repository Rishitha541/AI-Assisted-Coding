# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishitha541/AI-Assisted-Coding/blob/main/Assignment_13.1_2303A52149.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Rishitha Gangidi
# HT.NO : 2303a52149
# Batch : 35

# %% [markdown]
# # **Task 1: Rectangle Properties**

# %%
def calculate_rectangle_properties(length, width):
    """
    Calculate and print the area and perimeter of a rectangle.
    """
    # Area formula: length × width
    area = length * width
    # Perimeter formula: 2 × (length + width)
    perimeter = 2 * (length + width)

    # Display results
    print("Area of Rectangle:", area)
    print("Perimeter of Rectangle:", perimeter)

# Test cases
calculate_rectangle_properties(5, 10)
calculate_rectangle_properties(7, 12)
calculate_rectangle_properties(10, 15)
# Out:
# Area of Rectangle: 50
# Perimeter of Rectangle: 30
# Area of Rectangle: 84
# Perimeter of Rectangle: 38
# Area of Rectangle: 150
# Perimeter of Rectangle: 50

# %% [markdown]
# # **Task 2: Legacy vs Optimized Search**

# %%
import time

def legacy_search(names, search_names):
    """
    Perform search using nested loops (inefficient approach).
    """
    start = time.time()
    for s in search_names:
        found = False
        # Check each name one by one
        for n in names:
            if s == n:
                found = True
        # Print result for each search
        if found:
            print(f"{s} is in the list")
        else:
            print(f"{s} is not in the list")
    end = time.time()
    return end - start

def optimized_search(names, search_names):
    """
    Perform search using set lookup (optimized approach).
    """
    start = time.time()
    # Convert list to set for O(1) lookup
    names_set = set(names)
    for s in search_names:
        if s in names_set:
            print(f"{s} is in the list")
        else:
            print(f"{s} is not in the list")
    end = time.time()
    return end - start

# Input data
names = ["Alice", "Bob", "Charlie", "David"]
search_names = ["Charlie", "Eve", "Bob"]

print("---- Legacy Code Output ----")
legacy_time = legacy_search(names, search_names)

print("\n---- Optimized Code Output ----")
optimized_time = optimized_search(names, search_names)

# Compare performance
print("\n---- Performance Comparison ----")
print(f"Legacy Execution Time: {legacy_time:.8f} seconds")
print(f"Optimized Execution Time: {optimized_time:.8f} seconds")
# Out:
# ---- Legacy Code Output ----
# Charlie is in the list
# Eve is not in the list
# Bob is in the list
#
# ---- Optimized Code Output ----
# Charlie is in the list
# Eve is not in the list
# Bob is in the list
#
# ---- Performance Comparison ----
# Legacy Execution Time: 0.00001669 seconds
# Optimized Execution Time: 0.00001144 seconds

# %% [markdown]
# # **Task 3: Reusable Function for Tax**

# %%
def calculate_total(price):
    """
    Calculate the total price including 18% tax.
    """
    tax = price * 0.18
    total = price + tax
    return total

# Using the reusable function
print("Total Price:", calculate_total(250))
print("Total Price:", calculate_total(500))
# Out:
# Total Price: 295.0
# Total Price: 590.0

# %% [markdown]
# # **Task 4: Constants for Circle**

# %%
# Constants for readability
PI = 3.14159
RADIUS = 7

# Area formula: π × r²
area = PI * (RADIUS ** 2)
# Circumference formula: 2 × π × r
circumference = 2 * PI * RADIUS

print("Area of Circle:", area)
print("Circumference of Circle:", circumference)
# Out:
# Area of Circle: 153.93791
# Circumference of Circle: 43.98226

# %% [markdown]
# # **Task 5: Triangle Area**

# %%
# Base of the triangle
base = 10
# Height of the triangle
height = 20

# Formula: (base × height) / 2
area_of_triangle = base * height / 2

print("Area of Triangle:", area_of_triangle)
# Out:
# Area of Triangle: 100.0

# %% [markdown]
# # **Task 6: Grading Function**

# %%
def calculate_grade(marks):
    """
    Determine and print grade based on marks.
    """
    if marks >= 90:
        print("Grade A")
    elif marks >= 75:
        print("Grade B")
    else:
        print("Grade C")

# Test cases
calculate_grade(85)  # Expected Grade B
calculate_grade(72)  # Expected Grade C
# Out:
# Grade B
# Grade C

# %% [markdown]
# # **Task 7: Procedural to Functions**

# %%
def get_input():
    """
    Get a number from the user.
    """
    number = int(input("Enter number: "))
    return number

def calculate_square(number):
    """
    Return the square of a number.
    """
    return number * number

def display_result(result):
    """
    Display the calculated square.
    """
    print("Square:", result)

# Main program flow
num = get_input()
square = calculate_square(num)
display_result(square)
# Out:
# Enter number: 34
# Square: 1156

# %% [markdown]
# # **Task 8: List Comprehension**

# %%
# Original list of numbers
nums = [1, 2, 3, 4, 5]

# Using list comprehension to generate squares
squares = [n * n for n in nums]

# Display result
print("Squares:", squares)
# Out:
# Squares: [1, 4, 9, 16, 25]
